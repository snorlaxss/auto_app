# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM3-LiteText
#
# This notebook demonstrates how to use **SAM3-LiteText** for interactive video segmentation and dense tracking using the standard SAM3 video predictor API.
#
# **How it works**: The base SAM3 video model (ViT-H vision encoder + tracker) is loaded from HuggingFace. Then the text encoder is swapped with a lightweight MobileCLIP student variant, and the LiteText checkpoint weights are overlaid. This gives you the full SAM3 video capability with a much smaller text encoder.
#
# It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'

# %%
# !nvidia-smi
# Out:
# Wed Feb 18 21:15:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.07             Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 Ti     On  |   00000000:01:00.0  On |                  N/A |
# |  0%   35C    P8             10W /  285W |    1426MiB /  12282MiB |     12%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A              38      G   /Xwayland                             N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sys
import torch
import importlib

# Fix path to ensure we use the local sam3 package
notebook_dir = os.getcwd()
# Look for local 'sam3' folder (parent of efficientsam3_examples)
# Assuming notebook is in <root>/sam3/efficientsam3_examples:
local_sam3_root = os.path.abspath(os.path.join(notebook_dir, ".."))

if os.path.isdir(os.path.join(local_sam3_root, "sam3")):
    if local_sam3_root not in sys.path:
        sys.path.insert(0, local_sam3_root)
        print(f"Added {local_sam3_root} to sys.path")

import sam3
importlib.reload(sam3)
try:
    from sam3 import model_builder
    importlib.reload(model_builder)
    print(f"model_builder loaded from: {model_builder.__file__}")
except ImportError:
    pass
except Exception as e:
    print(f"Error reloading model_builder: {e}")

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")
print(f"Using sam3 from: {sam3_root}")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
# Out:
# Added /mnt/e/side_projects/efficientsam3/sam3 to sys.path
# model_builder loaded from: /mnt/e/side_projects/efficientsam3/sam3/sam3/model_builder.py
# Using sam3 from: /mnt/e/side_projects/efficientsam3/sam3/sam3/..
# /home/simon7108528_msi_linux/miniconda3/envs/efficientsam3/lib/python3.12/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor

bpe_path = f"{sam3_root}/assets/bpe_simple_vocab_16e6.txt.gz"

# LiteText image checkpoint — contains the student text encoder weights.
# The base SAM3 video model (ViT-H + tracker) is loaded from HuggingFace automatically.
checkpoint_path = "output/efficient_sam3_image_encoder_mobileclip_s0_ctx16.pt"

text_encoder_type = "MobileCLIP-S0"       # "MobileCLIP-S0", "MobileCLIP-S1", "MobileCLIP2-L"
text_encoder_context_length = 16           # 16, 32, or 77

predictor = build_sam3_video_predictor(
    gpus_to_use=gpus_to_use,
    checkpoint_path=checkpoint_path,
    bpe_path=bpe_path,
    text_encoder_type=text_encoder_type,
    text_encoder_context_length=text_encoder_context_length,
)
# Out:
# INFO 2026-02-18 21:15:33,600 604369 sam3_video_predictor.py: 329: using the following GPU IDs: [0]
# INFO 2026-02-18 21:15:33,601 604369 sam3_video_predictor.py: 345:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-02-18 21:15:33,601 604369 sam3_video_predictor.py: 347: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-02-18 21:15:38,767 604369 sam3_video_base.py: 124: setting max_num_objects=10000 and num_obj_for_compile=16
# Missing keys: ['detector.backbone.language_backbone.tensor_runner.encoder.projection_layer', 'detector.backbone.language_backbone.tensor_runner.encoder.embedding_layer.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.positional_embedding.pos_embed.pos_embed', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.layer_scale', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.layer_scale', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.norm.rbr_skip.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.norm.rbr_skip.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.norm.rbr_skip.running_mean', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.norm.rbr_skip.running_var', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_skip.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_skip.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_skip.running_mean', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_skip.running_var', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_conv.0.conv.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_conv.0.bn.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_conv.0.bn.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_conv.0.bn.running_mean', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.token_mixer.mixer.rbr_conv.0.bn.running_var', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.conv.conv.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.conv.bn.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.conv.bn.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.conv.bn.running_mean', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.conv.bn.running_var', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.fc1.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.fc1.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.fc2.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.0.convffn.fc2.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_mha.0.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_mha.0.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_mha.1.attn.in_proj_weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_mha.1.attn.in_proj_bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_mha.1.attn.out_proj.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_mha.1.attn.out_proj.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_ffn.0.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_ffn.0.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_ffn.1.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_ffn.1.bias', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_ffn.4.weight', 'detector.backbone.language_backbone.tensor_runner.encoder.transformer.1.pre_norm_ff ...
# Resizing positional embeddings from 77 to 16
# INFO 2026-02-18 21:15:46,679 604369 sam3_video_predictor.py: 349: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-02-18 21:15:46,680 604369 sam3_video_predictor.py: 360:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/0001"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (image folder) [rank=0]: 100%|██████████| 270/270 [00:05<00:00, 51.93it/s]

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
# propagate_in_video:   0%|          | 0/270 [00:00<?, ?it/s]
# propagate_in_video: 0it [00:00, ?it/s]

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 # we pick id 2, which is the dancer in the front
#       2 obj_id = 2
# ----> 3 response = predictor.handle_request(
#       4     request=dict(
#       5         type="remove_object",
#       6         session_id=session_id,
#       7         obj_id=obj_id,
#       8     )
#       9 )
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_predictor.py:377, in Sam3VideoPredictorMultiGPU.handle_request(self, request)
#     374     for rank in range(1, self.world_size):
#     375         self.command_queues[rank].put((request, False))
# --> 377 response = super().handle_request(request)
#     379 if self.world_size > 1:
#     380     torch.distributed.barrier()  # wait for all ranks to finish
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_predictor.py:104, in Sam3VideoPredictor.handle_request(self, request)
#      93     return self.add_prompt(
#      94         session_id=request["session_id"],
#      95         frame_idx=request["frame_index"],
#    (...)    101         obj_id=request.get("obj_id", None),
#     102     )
#     103 elif request_type == "remove_object":
# --> 104     return self.remove_object(
#     105         session_id=request["session_id"],
#     106         obj_id=request["obj_id"],
#     107         is_user_action=request.get("is_user_action", True),
#     108     )
#     109 elif request_type == "reset_session":
#     110     return self.reset_session(session_id=request["session_id"])
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_predictor.py:204, in Sam3VideoPredictor.remove_object(self, session_id, obj_id, is_user_action)
#     201 session = self._get_session(session_id)
#     202 inference_state = session["state"]
# --> 204 self.model.remove_object(
#     205     inference_state=inference_state,
#     206     obj_id=obj_id,
#     207     is_user_action=is_user_action,
#     208 )
#     209 return {"is_success": True}
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_inference.py:1283, in Sam3VideoInferenceWithInstanceInteractivity.remove_object(self, inference_state, obj_id, is_user_action)
#    1278 """
#    1279 We try to remove object from tracker states on every GPU, it will do nothing
#    1280 for states without this object.
#    1281 """
#    1282 obj_rank = self._get_gpu_id_by_obj_id(inference_state, obj_id)
# -> 1283 assert obj_rank is not None, f"Object {obj_id} not found in any GPU."
#    1285 tracker_states_local = inference_state["tracker_inference_states"]
#    1286 if self.rank == obj_rank:
#
# AssertionError: Object 2 not found in any GPU.

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
